# %% [markdown]
# **PANDAS**

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
f=[12,23,45,67,]
print(f)
# Out:
# [12, 23, 45, 67]

# %% [markdown]
# **Series

# %%
ds=pd.Series(f)
print(ds)
# Out:
# 0    12
# 1    23
# 2    45
# 3    67
# dtype: int64

# %% [markdown]
# **DATAFRAME:

# %%
data ={
    "name":["murtaza","aaqib","zeeshan"],
    "age":[22,23,22],
    "adress":["sogam","sogam","sogam"]
}
xy=pd.DataFrame(data)
xy
# Out:
#       name  age adress
# 0  murtaza   22  sogam
# 1    aaqib   23  sogam
# 2  zeeshan   22  sogam

# %%
import pandas as pd
data ={
    " players name":["murtaza","aaqib","zeeshan","saqib gucci","fasil","zubair","faian","danish",'abass',"rahil","shahid"],
    "jersey number":[13,11,6,67,7,5,8,3,1,12,56],
    "age":[22,22,22,18,25,19,21,21,22,23,20],
    "fees":[200,200,200,170,200,150,100,120,140,130,150],

}
df =pd.DataFrame(data)
df
# Out:
#     players name  jersey number  age  fees
# 0        murtaza             13   22   200
# 1          aaqib             11   22   200
# 2        zeeshan              6   22   200
# 3    saqib gucci             67   18   170
# 4          fasil              7   25   200
# 5         zubair              5   19   150
# 6          faian              8   21   100
# 7         danish              3   21   120
# 8          abass              1   22   140
# 9          rahil             12   23   130
# 10        shahid             56   20   150

# %%
data=pd.read_csv(r"C:\Users\USER\Downloads\DATA SETS\train.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
data.shape
# Out:
# (891, 12)

# %% [markdown]
# **iloc is to get a particulat item from a dataset but purely works on index**

# %%
data.iloc[0,3]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
data.iloc[7,8]
# Out:
# '349909'

# %% [markdown]
# **loc gets an individual data from dataset it worked with index and column names**

# %%
data.loc[0,'Ticket']
# Out:
# 'A/5 21171'

# %%
data.loc[5,'Fare']
# Out:
# np.float64(8.4583)

# %%
data.loc[5,'Name']
# Out:
# 'Moran, Mr. James'

# %% [markdown]
# ***AGREGATE FUNCTION***

# %%
data['Fare'].sum()
# Out:
# np.float64(28693.9493)

# %%
data['Age'].max()
# Out:
# np.float64(80.0)

# %%
data['Age'].min()
# Out:
# np.float64(0.42)

# %%
data['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
data['Age'].isnull().sum()
# Out:
# np.int64(177)

# %%
data['Age'].notnull().sum()
# Out:
# np.int64(714)

# %%
data['Fare'].mean()
# Out:
# np.float64(32.204207968574636)

# %%
data.sort_values(by='Age')
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
data.sort_values(by='Age',ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
data.sort_values(by='Fare',ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 438          439         0       1                   Fortune, Mr. Mark
# ..           ...       ...     ...                                 ...
# 806          807         0       1              Andrews, Mr. Thomas Jr
# 815          816         0       1                    Fry, Mr. Richard
# 466          467         0       2               Campbell, Mr. William
# 481          482         0       2    Frost, Mr. Anthony Wood "Archie"
# 822          823         0       1     Reuchlin, Jonkheer. John George
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.sort_values(by='Age', inplace=True)
data
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
data['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
data['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
data.head()
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 803  0.42      0      1    2625   8.5167   NaN        C
# 755  0.67      1      1  250649  14.5000   NaN        S
# 644  0.75      2      1    2666  19.2583   NaN        C
# 469  0.75      2      1    2666  19.2583   NaN        C
# 78   0.83      0      2  248738  29.0000   NaN        S

# %%
data['Survived']=data['Survived'].map({0:'Alive',1:'Dead'})
data.head()
# Out:
#      PassengerId Survived  Pclass                             Name     Sex  \
# 803          804     Dead       3  Thomas, Master. Assad Alexander    male
# 755          756     Dead       2        Hamalainen, Master. Viljo    male
# 644          645     Dead       3           Baclini, Miss. Eugenie  female
# 469          470     Dead       3    Baclini, Miss. Helene Barbara  female
# 78            79     Dead       2    Caldwell, Master. Alden Gates    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 803  0.42      0      1    2625   8.5167   NaN        C
# 755  0.67      1      1  250649  14.5000   NaN        S
# 644  0.75      2      1    2666  19.2583   NaN        C
# 469  0.75      2      1    2666  19.2583   NaN        C
# 78   0.83      0      2  248738  29.0000   NaN        S

# %% [markdown]
# **DATA MANIPULATION:---**
# Sorting,
# Filteration,
# Searching

# %%
data[data['Age']>18]
# Out:
#      PassengerId Survived  Pclass                                     Name  \
# 291          292     Dead       1  Bishop, Mrs. Dickinson H (Helen Walton)
# 566          567    Alive       3                     Stoytcheff, Mr. Ilia
# 546          547     Dead       2        Beane, Mrs. Edward (Ethel Clarke)
# 283          284     Dead       3               Dorking, Mr. Edward Arthur
# 302          303    Alive       3          Johnson, Mr. William Cahoone Jr
# ..           ...      ...     ...                                      ...
# 116          117    Alive       3                     Connors, Mr. Patrick
# 493          494    Alive       1                  Artagaveytia, Mr. Ramon
# 96            97    Alive       1                Goldschmidt, Mr. George B
# 851          852    Alive       3                      Svensson, Mr. Johan
# 630          631     Dead       1     Barkworth, Mr. Algernon Henry Wilson
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# ...

# %%
data[
    (data['Age']>18)&
    (data['Sex']=='male')
]
# Out:
#      PassengerId Survived  Pclass                                  Name   Sex  \
# 566          567    Alive       3                  Stoytcheff, Mr. Ilia  male
# 283          284     Dead       3            Dorking, Mr. Edward Arthur  male
# 302          303    Alive       3       Johnson, Mr. William Cahoone Jr  male
# 748          749    Alive       1             Marvin, Mr. Daniel Warner  male
# 372          373    Alive       3            Beavan, Mr. William Thomas  male
# ..           ...      ...     ...                                   ...   ...
# 116          117    Alive       3                  Connors, Mr. Patrick  male
# 493          494    Alive       1               Artagaveytia, Mr. Ramon  male
# 96            97    Alive       1             Goldschmidt, Mr. George B  male
# 851          852    Alive       3                   Svensson, Mr. Johan  male
# 630          631     Dead       1  Barkworth, Mr. Algernon Henry Wilson  male
#
# ...

# %%
alive_female_children=data[
    (data['Age']<18)&
    (data['Survived']==0)&
    (data['Sex']=='female')
]
alive_female_children
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
alive_female_children.shape
# Out:
# (0, 12)

# %%
Pclass_age_male=data[
    (data['Pclass']==3)&
    (data['Age']>10)&
    (data['Sex']=='male')
]
Pclass_age_male
# Out:
#      PassengerId Survived  Pclass                                Name   Sex  \
# 59            60    Alive       3  Goodwin, Master. William Frederick  male
# 731          732    Alive       3            Hassan, Mr. Houssein G N  male
# 125          126     Dead       3        Nicola-Yarred, Master. Elias  male
# 683          684    Alive       3         Goodwin, Mr. Charles Edward  male
# 686          687    Alive       3            Panula, Mr. Jaako Arnold  male
# ..           ...      ...     ...                                 ...   ...
# 94            95    Alive       3                   Coxon, Mr. Daniel  male
# 326          327    Alive       3           Nysveen, Mr. Johan Hansen  male
# 280          281    Alive       3                    Duane, Mr. Frank  male
# 116          117    Alive       3                Connors, Mr. Patrick  male
# 851          852    Alive       3                 Svensson, Mr. Johan  male
#
#       Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# ...

# %%
fare_age=data[
    (data['Fare']>5)&
    (data['Age']>70)
]
fare_age
# Out:
#      PassengerId Survived  Pclass                                  Name   Sex  \
# 116          117    Alive       3                  Connors, Mr. Patrick  male
# 493          494    Alive       1               Artagaveytia, Mr. Ramon  male
# 96            97    Alive       1             Goldschmidt, Mr. George B  male
# 851          852    Alive       3                   Svensson, Mr. Johan  male
# 630          631     Dead       1  Barkworth, Mr. Algernon Henry Wilson  male
#
#       Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 116  70.5      0      0    370369   7.7500   NaN        Q
# 493  71.0      0      0  PC 17609  49.5042   NaN        C
# 96   71.0      0      0  PC 17754  34.6542    A5        C
# 851  74.0      0      0    347060   7.7750   NaN        S
# 630  80.0      0      0     27042  30.0000   A23        S

# %%
data.head()
# Out:
#      PassengerId Survived  Pclass                             Name     Sex  \
# 803          804     Dead       3  Thomas, Master. Assad Alexander    male
# 755          756     Dead       2        Hamalainen, Master. Viljo    male
# 644          645     Dead       3           Baclini, Miss. Eugenie  female
# 469          470     Dead       3    Baclini, Miss. Helene Barbara  female
# 78            79     Dead       2    Caldwell, Master. Alden Gates    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 803  0.42      0      1    2625   8.5167   NaN        C
# 755  0.67      1      1  250649  14.5000   NaN        S
# 644  0.75      2      1    2666  19.2583   NaN        C
# 469  0.75      2      1    2666  19.2583   NaN        C
# 78   0.83      0      2  248738  29.0000   NaN        S

# %%
data[data['Name'].str.contains('Braund')]
# Out:
#      PassengerId Survived  Pclass                       Name   Sex   Age  \
# 0              1    Alive       3    Braund, Mr. Owen Harris  male  22.0
# 477          478    Alive       3  Braund, Mr. Lewis Richard  male  29.0
#
#      SibSp  Parch     Ticket    Fare Cabin Embarked
# 0        1      0  A/5 21171  7.2500   NaN        S
# 477      1      0       3460  7.0458   NaN        S

# %%
data[data['Name'].str.contains('Miss')]
# Out:
#      PassengerId Survived  Pclass                                      Name  \
# 644          645     Dead       3                    Baclini, Miss. Eugenie
# 469          470     Dead       3             Baclini, Miss. Helene Barbara
# 172          173     Dead       3              Johnson, Miss. Eleanor Ileen
# 381          382     Dead       3               Nakid, Miss. Maria ("Mary")
# 642          643    Alive       3             Skoog, Miss. Margit Elizabeth
# ..           ...      ...     ...                                       ...
# 697          698     Dead       3          Mullens, Miss. Katherine "Katie"
# 727          728     Dead       3                  Mannion, Miss. Margareth
# 792          793    Alive       3                   Sage, Miss. Stella Anna
# 863          864    Alive       3         Sage, Miss. Dorothy Edith "Dolly"
# 888          889    Alive       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
data[data['Name'].str.contains('Duran')]
# Out:
#      PassengerId Survived  Pclass                          Name     Sex   Age  \
# 866          867     Dead       2  Duran y More, Miss. Asuncion  female  27.0
#
#      SibSp  Parch         Ticket     Fare Cabin Embarked
# 866      1      0  SC/PARIS 2149  13.8583   NaN        C

# %%
data[data['Ticket'].str.contains('SC/PARIS 2149')]
# Out:
#      PassengerId Survived  Pclass                          Name     Sex   Age  \
# 866          867     Dead       2  Duran y More, Miss. Asuncion  female  27.0
#
#      SibSp  Parch         Ticket     Fare Cabin Embarked
# 866      1      0  SC/PARIS 2149  13.8583   NaN        C

# %%
data.iloc[0,3]='murtaza'
data.head()
# Out:
#      PassengerId Survived  Pclass                           Name     Sex  \
# 803          804     Dead       3                        murtaza    male
# 755          756     Dead       2      Hamalainen, Master. Viljo    male
# 644          645     Dead       3         Baclini, Miss. Eugenie  female
# 469          470     Dead       3  Baclini, Miss. Helene Barbara  female
# 78            79     Dead       2  Caldwell, Master. Alden Gates    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 803  0.42      0      1    2625   8.5167   NaN        C
# 755  0.67      1      1  250649  14.5000   NaN        S
# 644  0.75      2      1    2666  19.2583   NaN        C
# 469  0.75      2      1    2666  19.2583   NaN        C
# 78   0.83      0      2  248738  29.0000   NaN        S

# %%
data.replace('Allen, Mr. William Henry','murtaza mir',inplace=True)
# Out:
#      PassengerId Survived  Pclass                                      Name  \
# 803          804     Dead       3                                   murtaza
# 755          756     Dead       2                 Hamalainen, Master. Viljo
# 644          645     Dead       3                    Baclini, Miss. Eugenie
# 469          470     Dead       3             Baclini, Miss. Helene Barbara
# 78            79     Dead       2             Caldwell, Master. Alden Gates
# ..           ...      ...     ...                                       ...
# 859          860    Alive       3                          Razi, Mr. Raihed
# 863          864    Alive       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869    Alive       3               van Melkebeke, Mr. Philemon
# 878          879    Alive       3                        Laleff, Mr. Kristo
# 888          889    Alive       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
data.head()
# Out:
#      PassengerId Survived  Pclass                           Name     Sex  \
# 803          804     Dead       3                        murtaza    male
# 755          756     Dead       2      Hamalainen, Master. Viljo    male
# 644          645     Dead       3         Baclini, Miss. Eugenie  female
# 469          470     Dead       3  Baclini, Miss. Helene Barbara  female
# 78            79     Dead       2  Caldwell, Master. Alden Gates    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 803  0.42      0      1    2625   8.5167   NaN        C
# 755  0.67      1      1  250649  14.5000   NaN        S
# 644  0.75      2      1    2666  19.2583   NaN        C
# 469  0.75      2      1    2666  19.2583   NaN        C
# 78   0.83      0      2  248738  29.0000   NaN        S

# %%
data[data['Sex'].isin(['male'])]
# Out:
#      PassengerId Survived  Pclass                             Name   Sex  \
# 803          804     Dead       3                          murtaza  male
# 755          756     Dead       2        Hamalainen, Master. Viljo  male
# 78            79     Dead       2    Caldwell, Master. Alden Gates  male
# 831          832     Dead       2  Richards, Master. George Sibley  male
# 305          306     Dead       1   Allison, Master. Hudson Trevor  male
# ..           ...      ...     ...                              ...   ...
# 839          840     Dead       1             Marechal, Mr. Pierre  male
# 846          847    Alive       3         Sage, Mr. Douglas Bullen  male
# 859          860    Alive       3                 Razi, Mr. Raihed  male
# 868          869    Alive       3      van Melkebeke, Mr. Philemon  male
# 878          879    Alive       3               Laleff, Mr. Kristo  male
#
#       Age  SibSp  Parch    Ticket      Fare    Cabin Embarked
# ...

# %%
data.head()
# Out:
#      PassengerId Survived  Pclass                           Name     Sex  \
# 803          804     Dead       3                        murtaza    male
# 755          756     Dead       2      Hamalainen, Master. Viljo    male
# 644          645     Dead       3         Baclini, Miss. Eugenie  female
# 469          470     Dead       3  Baclini, Miss. Helene Barbara  female
# 78            79     Dead       2  Caldwell, Master. Alden Gates    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 803  0.42      0      1    2625   8.5167   NaN        C
# 755  0.67      1      1  250649  14.5000   NaN        S
# 644  0.75      2      1    2666  19.2583   NaN        C
# 469  0.75      2      1    2666  19.2583   NaN        C
# 78   0.83      0      2  248738  29.0000   NaN        S

# %%
data.groupby('Sex')['Survived'].sum()
# Out:
# Sex
# female    DeadDeadDeadDeadAliveAliveDeadAliveAliveDeadAl...
# male      DeadDeadDeadDeadDeadAliveDeadAliveDeadDeadAliv...
# Name: Survived, dtype: str

# %%
data['Sex']=data['Sex'].map({'male':0,'female':1})

# %%
data.groupby('Survived')['Sex'].sum()
# Out:
# Survived
# Alive     81
# Dead     233
# Name: Sex, dtype: int64

# %%
data['Survived']=data['Survived'].map({1:0,0:1})

# %%
data.groupby('Sex')['Survived'].sum()
# Out:
# Sex
# 0    0.0
# 1    0.0
# Name: Survived, dtype: float64

# %%
data.groupby('Pclass')['Survived'].sum()
# Out:
# Pclass
# 1    0.0
# 2    0.0
# 3    0.0
# Name: Survived, dtype: float64

# %%
data.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# 0   NaN
# 1   NaN
# Name: Survived, dtype: float64

# %%
data['Sex']=data['Sex'].map({'female':0,'male':1})

# %%
data.groupby('Survived')['Sex'].sum()
# Out:
# Series([], Name: Sex, dtype: float64)

# %%
data.head()
# Out:
#      PassengerId  Survived  Pclass                           Name  Sex   Age  \
# 803          804       NaN       3                        murtaza  NaN  0.42
# 755          756       NaN       2      Hamalainen, Master. Viljo  NaN  0.67
# 644          645       NaN       3         Baclini, Miss. Eugenie  NaN  0.75
# 469          470       NaN       3  Baclini, Miss. Helene Barbara  NaN  0.75
# 78            79       NaN       2  Caldwell, Master. Alden Gates  NaN  0.83
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked
# 803      0      1    2625   8.5167   NaN        C
# 755      1      1  250649  14.5000   NaN        S
# 644      2      1    2666  19.2583   NaN        C
# 469      2      1    2666  19.2583   NaN        C
# 78       0      2  248738  29.0000   NaN        S

# %%
data['Survived'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
data['Age'].isnull().sum()
# Out:
# np.int64(177)

# %%
data['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
data.dropna(subset='Age')
# Out:
#      PassengerId  Survived  Pclass                                  Name  Sex  \
# 803          804       NaN       3                               murtaza  NaN
# 755          756       NaN       2             Hamalainen, Master. Viljo  NaN
# 644          645       NaN       3                Baclini, Miss. Eugenie  NaN
# 469          470       NaN       3         Baclini, Miss. Helene Barbara  NaN
# 78            79       NaN       2         Caldwell, Master. Alden Gates  NaN
# ..           ...       ...     ...                                   ...  ...
# 116          117       NaN       3                  Connors, Mr. Patrick  NaN
# 493          494       NaN       1               Artagaveytia, Mr. Ramon  NaN
# 96            97       NaN       1             Goldschmidt, Mr. George B  NaN
# 851          852       NaN       3                   Svensson, Mr. Johan  NaN
# 630          631       NaN       1  Barkworth, Mr. Algernon Henry Wilson  NaN
#
# ...

# %%
data['Age']=data['Age'].fillna(data['Age'].mean())

# %%
data['Age'].isnull().sum()
# Out:
# np.int64(0)

# %%
female_alive_children=data[
    (data['Age']<18)&
    (data['Sex']=='female')&
    (data['Survived']==1)

]

# %%
female_alive_children.to_csv('children.csv')

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
female_alive_children.to_excel('children.xlsx')

# %%
children =pd.read_excel("children.xlsx")
